# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
Nombre_modelo=['Interpolacion día atras','Interpolacion semana atrás','Interpolacion un año atrás','Arima','CNN Univariable','CNN Multi canal','Vanilla LSTM','LSTM Encoder-Decoder','E-D LSTM Multi/Vble','CNN-LSTM Univariable','CNN-LSTM Multivariable','ConvLSTM univariable']
Indice=['Interpolacion día atras','Interpolacion semana atrás','Interpolacion un año atrás','Arima','CNN Univariable','CNN Multi canal','Vanilla LSTM','LSTM Encoder-Decoder','E-D LSTM Multi/Vble','CNN-LSTM Univariable','CNN-LSTM Multivariable','ConvLSTM univariable']
CP=['Si','Si','Si','Si','Si','Si','Si','Si','Si','No','No','No']
Puntaje=[511.886,469.389,465.294,381.599,378.444,383.737,379.179,373.447,466.181,379.849,364.123,389.534]

Data={'Indice':Nombre_modelo, 'Nombre_modelo':Nombre_modelo, 'Puntaje':Puntaje, 'Modelo de Control?':CP}

Data=DataFrame(data=Data, index=Indice)

# %%
Data
# Out:
#                                                 Indice  \
# Interpolacion día atras        Interpolacion día atras
# Interpolacion semana atrás  Interpolacion semana atrás
# Interpolacion un año atrás  Interpolacion un año atrás
# Arima                                            Arima
# CNN Univariable                        CNN Univariable
# CNN Multi canal                        CNN Multi canal
# Vanilla LSTM                              Vanilla LSTM
# LSTM Encoder-Decoder              LSTM Encoder-Decoder
# E-D LSTM Multi/Vble                E-D LSTM Multi/Vble
# CNN-LSTM Univariable              CNN-LSTM Univariable
# CNN-LSTM Multivariable          CNN-LSTM Multivariable
# ConvLSTM univariable              ConvLSTM univariable
#
#                                          Nombre_modelo  Puntaje  \
# Interpolacion día atras        Interpolacion día atras  511.886
# Interpolacion semana atrás  Interpolacion semana atrás  469.389
# ...

# %%
Data.describe()
# Out:
#           Puntaje
# count   12.000000
# mean   411.888500
# std     50.712722
# min    364.123000
# 25%    378.995250
# 50%    382.668000
# 75%    465.515750
# max    511.886000

# %%
colours ={
'Interpolacion día atras':"#44bd32"
,'Interpolacion semana atrás':"#273c75"
,'Interpolacion un año atrás':"#273c75"
,'Arima':"#273c75"
,'CNN Univariable':"#273c75"
,'CNN Multi canal':"#273c75"
,'Vanilla LSTM':"#273c75"
,'LSTM Encoder-Decoder':"#273c75"
,'E-D LSTM Multi/Vble':"#273c75"
,'CNN-LSTM Univariable':"#273c75"
,'CNN-LSTM Multivariable':"#273c75"
,'ConvLSTM univariable':"#273c75"
}
Data.sort_values(by='Puntaje',ascending=False).plot(kind='barh',figsize=(10,10)
,title='Gráfica de resultados sobre RMSE'
,legend=True
,ylabel='RMSE'
,xlabel='Nombre del Modelo'
# ,color=Data['Nombre_modelo'].replace(colours)
)
# Out:
# <AxesSubplot:title={'center':'Gráfica de resultados sobre RMSE'}, ylabel='Nombre del Modelo'>
